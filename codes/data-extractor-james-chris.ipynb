# %%
import json
import sqlite3
import pandas as pd

#connection to database
PATH = '../data/narayananbadri_g4mp2gdb9_database_v1.1/data/g4mp2-gdb9.db'
sql_connect = sqlite3.connect(PATH)
cursor = sql_connect.cursor()

#SQL query
#NOTE: remove LIMIT 10 to get all key_value_pairs
query = "SELECT id, key_value_pairs FROM systems LIMIT 10;"
results = cursor.execute(query).fetchall()

#append values in list
df = pd.read_sql_query(query, sql_connect)
results = list()
for value in df['key_value_pairs']:
  results.append(value)

#write values into json
with open('results.json', 'w') as outfile:
  outfile.write("{\n\"key_value_pairs\":[\n")
  for i in range(len(results) - 1):
    outfile.write(results[i])
    outfile.write(",\n")
  outfile.write(results[-1])
  outfile.write("]}")

#open json file
with open('results.json', 'r') as infile:
  data = json.load(infile)

#dictionary for SMILES string
smiles_data = dict()
for i in range(len(data['key_value_pairs'])):
  smiles_data[i] = data['key_value_pairs'][0]['Smiles']

print(smiles_data)

# Initial work to modify the g4mp2_data.json file
# with open('g4mp2_data.json', 'r') as infile:
#   data = infile.read()
# data = data.replace("\n", ",\n")

# with open('g4mp2_data_modified.json', 'w') as outfile:
#   outfile.write("{\n\"data\":[\n")
#   outfile.write(data)
#   outfile.write("]}")

#open json file
# with open('g4mp2_data_modified.json', 'r') as infile:
#   data = json.load(infile)
#   data = data['data']

data = data['data']

#dictionary for SMILES string
homo_lumo_data = dict()
for i in range(len(data)):
  homo_lumo_data[i] = dict()
  homo_lumo_data[i]['homo'] = data[i]['homo']
  homo_lumo_data[i]['lumo'] = data[i]['lumo']
  homo_lumo_data[i]['index'] = data[i]['index']

for i in range(10):
  print(homo_lumo_data[i])


sql_connect.close()
# Out:
# {0: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 1: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 2: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 3: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 4: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 5: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 6: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 7: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 8: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34', 9: 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-333377497032> in <module>
#      54 #   data = data['data']
#      55
# ---> 56 data = data['data']
#      57
#      58 #dictionary for SMILES string
#
# KeyError: 'data'

# %%
data
# Out:
# {'key_value_pairs': [{'g4mp2_Standard_Enthalpy_Formation': 35.19166,
#    'g4mp2_Enthalpy': -437.311525,
#    'Smiles': 'O[C@H]1[C@H]2[C@H]3O[C@H]4[C@@H]1N2[C@@H]34',
#    'Plain_InChI': 'InChI=1S/C6H7NO2/c8-4-1-5-3-6(9-5)2(4)7(1)3/h1-6,8H',
#    'g4mp2_ZPE': 0.125447,
#    'g4mp2_FreeE': -437.348073,
#    'g4mp2_AtomizationE': 1569.140848,
#    'Plain_Smiles': 'OC1C2C3OC4C1N2C34',
#    'g4mp2_E0K': -437.318254,
#    'g4mp2_Energy': -437.312469,
#    'InChI': 'InChI=1S/C6H7NO2/c8-4-1-5-3-6(9-5)2(4)7(1)3/h1-6,8H/t1-,2+,3-,4-,5+,6-',
#    'gdbID': 79782},
#   {'g4mp2_Standard_Enthalpy_Formation': 103.123826,
#    'g4mp2_Enthalpy': -373.267434,
#    'Smiles': '[NH][C]1N=CC=NC=N1',
#    'Plain_InChI': 'InChI=1S/C4H4N4/c5-4-7-2-1-6-3-8-4/h1-3,5H',
#    'g4mp2_ZPE': 0.084785,
#    'g4mp2_FreeE': -373.304676,
#    'g4mp2_AtomizationE': 1228.659484,
#    'Plain_Smiles': 'N=C1N=CC=NC=N1',
#    'g4mp2_E0K': -373.274483,
#    'g4mp2_Energy': -373.268379,
#    'InChI': 'InChI=1S/C4H4N4/c5-4-7-2-1-6-3-8-4/h1-3,5H',
#    'gdbID': 5049},
#   {'g4mp2_Standard_Enthalpy_Formation': 10.408706,
#    'g4mp2_Enthalpy': -385.423348,
#    'Smiles': 'C[C@@]12C[C@H]3C[C@@H]1C(=O)[C@@H]23',
#    'Plain_InChI': 'InChI=1S/C8H10O/c1-8-3-4-2-5(8)7(9)6(4)8/h4-6H,2-3H2,1H3',
#    'g4mp2_ZPE': 0.158545,
#    'g4mp2_FreeE': -385.463053,
#    'g4mp2_AtomizationE': 1916.790874,
#    'Plain_Smiles': 'CC12CC3CC1C(=O)C23',
#    'g4mp2_E0K': -385.43165,
#    'g4mp2_Energy': -385.424293,
#    'InChI': 'InChI=1S/C8H10O/c1-8-3-4-2-5(8)7(9)6(4)8/h4-6H,2-3H2,1H3/t4-,5-,6+,8-/m1/s1',
#    'gdbID': 72010},
#   {'g4mp2_Standard_Enthalpy_Formation': 52.787736,
#    'g4mp2_Enthalpy': -448.442482,
#    'Smiles': 'Nc1n[nH]c2c1ocn2',
#    'Plain_InChI': 'InChI=1S/C4H4N4O/c5-3-2-4(8-7-3)6-1-9-2/h1H,(H3,5,7,8)',
#    'g4mp2_ZPE': 0.091877,
#    'g4mp2_FreeE': -448.481342,
#    'g4mp2_AtomizationE': 1337.413069,
#    'Plain_Smiles': 'NC1=NNC2=C1OC=N2',
#    'g4mp2_E0K': -448.450276,
#    'g4mp2_Energy': -448.443426,
#    'InChI': 'InChI=1S/C4H4N4O/c5-3-2-4(8-7-3)6-1-9-2/h1H,(H3,5,7,8)',
#    'gdbID': 130188},
#   {'g4mp2_Standard_Enthalpy_Formation': 80.86012,
#    'g4mp2_Enthalpy': -342.342341,
#    'Smiles': 'N#C[C@H]1N[C@H]1C1CC1',
#    'Plain_InChI': 'InChI=1S/C6H8N2/c7-3-5-6(8-5)4-1-2-4/h4-6,8H,1-2H2',
#    'g4mp2_ZPE': 0.129373,
#    'g4mp2_FreeE': -342.383555,
#    'g4mp2_AtomizationE': 1570.864615,
#    'Plain_Smiles': 'N#CC1NC1C1CC1',
#    'g4mp2_E0K': -342.350954,
#    'g4mp2_Energy': -342.343285,
#    'InChI': 'InChI=1S/C6H8N2/c7-3-5-6(8-5)4-1-2-4/h4-6,8H,1-2H2/t5-,6+/m1/s1',
#    'gdbID': 19995},
#   {'g4mp2_Standard_Enthalpy_Formation': 35.601008,
#    'g4mp2_Enthalpy': -434.979824,
#    'Smiles': 'CC(=O)C#CC(=O)C#N',
#    'Plain_InChI': 'InChI=1S/C6H3NO2/c1-5(8)2-3-6(9)4-7/h1H3',
#    'g4mp2_ZPE': 0.072837,
#    'g4mp2_FreeE': -435.026782,
#    'g4mp2_AtomizationE': 1368.567636,
#    'Plain_Smiles': 'CC(=O)C#CC(=O)C#N',
#    'g4mp2_E0K': -434.990244,
#    'g4mp2_Energy': -434.980769,
#    'InChI': 'InChI=1S/C6H3NO2/c1-5(8)2-3-6(9)4-7/h1H3',
#    'gdbID': 53722},
#   {'g4mp2_Standard_Enthalpy_Formation': 99.88667,
#    'g4mp2_Enthalpy': -364.313657,
#    'Smiles': 'CC1=CC[C@]2(N[C@@H]12)C#C',
#    'Plain_InChI': 'InChI=1S/C8H9N/c1-3-8-5-4-6(2)7(8)9-8/h1,4,7,9H,5H2,2H3',
#    'g4mp2_ZPE': 0.144971,
#    'g4mp2_FreeE': -364.355812,
#    'g4mp2_AtomizationE': 1830.957683,
#    'Plain_Smiles': 'CC1=CCC2(NC12)C#C',
#    'g4mp2_E0K': -364.323114,
#    'g4mp2_Energy': -364.314601,
#    'InChI': 'InChI=1S/C8H9N/c1-3-8-5-4-6(2)7(8)9-8/h1,4,7,9H,5H2,2H3/t7-,8+/m0/s1',
#    'gdbID': 75220},
#   {'g4mp2_Standard_Enthalpy_Formation': -14.314472,
#    'g4mp2_Enthalpy': -403.856844,
#    'Smiles': 'CN1[C@H]2CCOC[C@@]12C',
#    'Plain_InChI': 'InChI=1S/C7H13NO/c1-7-5-9-4-3-6(7)8(7)2/h6H,3-5H2,1-2H3',
#    'g4mp2_ZPE': 0.192197,
#    'g4mp2_FreeE': -403.899666,
#    'g4mp2_AtomizationE': 2036.147478,
#    'Plain_Smiles': 'CN1C2CCOCC12C',
#    'g4mp2_E0K': -403.866761,
#    'g4mp2_Energy': -403.857788,
#    'InChI': 'InChI=1S/C7H13NO/c1-7-5-9-4-3-6(7)8(7)2/h6H,3-5H2,1-2H3/t6-,7+,8?/m0/s1',
#    'gdbID': 84018},
#   {'g4mp2_Standard_Enthalpy_Formation': 21.207037,
#    'g4mp2_Enthalpy': -433.595285,
#    'Smiles': 'O[C@]12C[C@H]1N=CN[C]2[NH]',
#    'Plain_InChI': 'InChI=1S/C5H7N3O/c6-4-5(9)1-3(5)7-2-8-4/h2-3,9H,1H2,(H2,6,7,8)',
#    'g4mp2_ZPE': 0.124545,
#    'g4mp2_FreeE': -433.635259,
#    'g4mp2_AtomizationE': 1579.485334,
#    'Plain_Smiles': 'OC12CC1N=CNC2=N',
#    'g4mp2_E0K': -433.603703,
#    'g4mp2_Energy': -433.596229,
#    'InChI': 'InChI=1S/C5H7N3O/c6-4-5(9)1-3(5)7-2-8-4/h2-3,9H,1H2,(H2,6,7,8)/t3-,5-/m1/s1',
#    'gdbID': 70139},
#   {'g4mp2_Standard_Enthalpy_Formation': -78.932619,
#    'g4mp2_Enthalpy': -423.761394,
#    'Smiles': 'C[C@@H](O)[C@H]1OCC(=C1)C',
#    'Plain_InChI': 'InChI=1S/C7H12O2/c1-5-3-7(6(2)8)9-4-5/h3,6-8H,4H2,1-2H3',
#    'g4mp2_ZPE': 0.178025,
#    'g4mp2_FreeE': -423.807248,
#    'g4mp2_AtomizationE': 1997.24192,
#    'Plain_Smiles': 'CC(O)C1OCC(C)=C1',
#    'g4mp2_E0K': -423.772325,
#    'g4mp2_Energy': -423.762338,
#    'InChI': 'InChI=1S/C7H12O2/c1-5-3-7(6(2)8)9-4-5/h3,6-8H,4H2,1-2H3/t6-,7+/m1/s1',
#    'gdbID': 59637}]}
